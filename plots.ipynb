# %%
import pandas as pd
import matplotlib.pyplot as mat

# %% [markdown]
# # starting to explore pandas and matplotlib

# %%
airqua = pd.read_csv("data/air_quality_no2.csv") 
airqua
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]

# %%
airqua.shape
# Out:
# (1035, 4)

# %% [markdown]
# airqua.info()

# %%
airqua.dtypes
# Out:
# datetime            object
# station_antwerp    float64
# station_paris      float64
# station_london     float64
# dtype: object

# %%
airqua.columns
# Out:
# Index(['datetime', 'station_antwerp', 'station_paris', 'station_london'], dtype='object')

# %%
#Making first column as 0th index
airq=pd.read_csv("data/air_quality_no2.csv",index_col=0,parse_dates=True)

# %%
airq.plot()
mat.title("Air Quality").set_color("purple")
mat.xlabel('Dates').set_color('Red') 
mat.ylabel('Values').set_color('blue')

# %%
airq.plot.box()
# Out:
# <AxesSubplot:>

# %%
airq.plot.hexbin('station_paris','station_london',gridsize=(10,10))
# Out:
# <AxesSubplot:xlabel='station_paris', ylabel='station_london'>

# %%
airq.plot.area(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
airq.plot.area(figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
airq.plot.area(figsize=(12,4),subplots=True)
# Out:
# array([<AxesSubplot:xlabel='datetime'>, <AxesSubplot:xlabel='datetime'>,
#        <AxesSubplot:xlabel='datetime'>], dtype=object)

# %%
#setting up parameter,title and label with name and colors
airq["station_antwerp"].plot()
mat.tick_params(axis='x', colors='black')
mat.tick_params(axis='y', colors='purple')
mat.title("Antwerp").set_color('blue')
mat.ylabel('Values').set_color('Orange')
mat.xlabel('Dates').set_color('red')

# %%
airq["station_paris"].plot()
mat.title("Pairs")
mat.tick_params()

# %%
airq["station_london"].plot()
mat.title("London").set_color("Red")

# %%
#comparing air quality of two cities
airq.plot.scatter(x="station_london",y="station_paris",color=['red'],alpha=0.3)
mat.title('Paris Vs London').set_color("red")

# %%
airqua.dtypes
# Out:
# datetime            object
# station_antwerp    float64
# station_paris      float64
# station_london     float64
# dtype: object

# %%
airqua.plot.scatter(x='station_antwerp',y='station_london',alpha=0.5)
mat.title('London Vs Antwerp').set_color('Blue')
